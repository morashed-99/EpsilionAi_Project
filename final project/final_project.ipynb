# %% [markdown]
# # Project  Overview

# %% [markdown]
# #### The project will analyze a dataset containing 1960 rows and 26  columns, including:
#  Sales Data: Sales, Profit, Discount, Unit Price, Shipping Cost,
#  Quantity Ordered.
#  Customer Data: Customer ID, Customer Name, Customer
#  Segment, Region, Country, State, City, Postal Code.
#  Product Data: Product Category, Product Sub-Category,
#  Product Name, Product Container, Product Base Margin.
#  Order Data: Order ID, Order Priority, Order Date, Ship Date,
#  Ship Mode.
#  Other Data: Manager, Status (mostly missing).
#  The analysis will cover:
#  Sales performance by region, product category, and
#  customer segment.
#  Customer behavior and segmentation.
#  Shipping and order fulfillment efficiency.
#  Profitability analysis.
#  Identification of key drivers of sales and profit

# %% [markdown]
# # Project  Objectives

# %% [markdown]
# ### Sales Analysis:

# %% [markdown]
# ##### 1-Analyze total sales, profit, and discounts by region, product category, and customer segment.
# ##### 2-Identify top-performing productsand regions.

# %% [markdown]
# ### Customer Analysis:

# %% [markdown]
# ##### 1- Segment customers based on purchasing behavior and demographics.
# ##### 2- Identify high-value customers and their preferences.

# %% [markdown]
# ### Shipping and  Order  Fulfillment:

# %% [markdown]
# ##### 1- Evaluate shipping costs and delivery times by ship mode and region.
# ##### 2- Identify inefficiencies in the order fulfillment process.

# %% [markdown]
# ### Profitability Analysis:

# %% [markdown]
# ##### 1- Analyze profit margins by product category and sub-category.
# ##### 2- Identify factors affecting profitability (e.g., discounts,shipping costs).

# %% [markdown]
# ### Data Cleaning and Preparation:

# %% [markdown]
# ##### 1- Handle missing values in columns like Order Priority, Customer Name, Ship Mode, and Product Base Margin.
# ##### 2- Convert data types (e.g., Order Date and Ship Date to datetime).

# %% [markdown]
# ### Reporting and Visualization:

# %% [markdown]
# ##### 1- Create dashboards and reports to present key insights.
# ##### 2- Use Python libraries (e.g., plotly, seaborn).

# %%
# import libiraries
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime

# %% [markdown]
# # Reading csv file

# %%
# reading csv 
df = pd.read_csv(r"D:\data course\epsilion\Mohamed Osama Rashed\Epsilion_proj.csv")
# drop Unnamed: 0 column
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#        Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0         NaN            NaN       NaN         NaN            NaN
# 1         NaN            NaN       NaN         NaN            NaN
# 2         NaN            NaN       NaN         NaN            NaN
# 3         NaN            NaN       NaN         NaN            NaN
# 4         NaN            NaN       NaN         NaN            NaN
# ...       ...            ...       ...         ...            ...
# 1964  24014.0         Medium      0.04      300.98          54.92
# 1965  18495.0         Medium      0.09        2.88           1.49
# 1966  19074.0           High      0.03        4.26           1.20
# 1967  19950.0         Medium      0.01        4.91           0.50
# 1968  19951.0         Medium      0.09        4.00           1.30
#
#       Customer ID  Customer Name       Ship Mode Customer Segment  \
# 0             NaN            NaN             NaN              NaN
# ...

# %% [markdown]
# # Data Understanding

# %%
df.shape
# Out:
# (1969, 27)

# %%
# info about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1969 entries, 0 to 1968
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1960 non-null   float64
#  1   Order Priority        1955 non-null   object
#  2   Discount              1960 non-null   float64
#  3   Unit Price            1960 non-null   float64
#  4   Shipping Cost         1960 non-null   float64
#  5   Customer ID           1960 non-null   float64
#  6   Customer Name         1958 non-null   object
#  7   Ship Mode             1954 non-null   object
#  8   Customer Segment      1960 non-null   object
#  9   Product Category      1960 non-null   object
#  10  Product Sub-Category  1960 non-null   object
#  11  Product Container     1960 non-null   object
#  12  Product Name          1960 non-null   object
#  13  Product Base Margin   1944 non-null   float64
# ...

# %%
# how many nulls
df.isnull().sum()
# Out:
# Row ID                     9
# Order Priority            14
# Discount                   9
# Unit Price                 9
# Shipping Cost              9
# Customer ID                9
# Customer Name             11
# Ship Mode                 15
# Customer Segment           9
# Product Category           9
# Product Sub-Category       9
# Product Container          9
# Product Name               9
# Product Base Margin       25
# Country                    9
# Region                     9
# State or Province         14
# City                      15
# Postal Code               17
# Order Date                 9
# Ship Date                  9
# Profit                     9
# Quantity ordered new       9
# Sales                      9
# Order ID                   9
# Status                  1954
# Manager                    9
# dtype: int64

# %%
# first 10 columns
df.head(10)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      NaN            NaN       NaN         NaN            NaN          NaN
# 1      NaN            NaN       NaN         NaN            NaN          NaN
# 2      NaN            NaN       NaN         NaN            NaN          NaN
# 3      NaN            NaN       NaN         NaN            NaN          NaN
# 4      NaN            NaN       NaN         NaN            NaN          NaN
# 5      NaN            NaN       NaN         NaN            NaN          NaN
# 6      NaN            NaN       NaN         NaN            NaN          NaN
# 7      NaN            NaN       NaN         NaN            NaN          NaN
# 8      NaN            NaN       NaN         NaN            NaN          NaN
# 9  20847.0           High      0.01        2.84           0.93          3.0
#
#    Customer Name    Ship Mode Customer Segment Product Category  ...  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
# drop first 9 null rows
df.drop(df.index[:9],inplace=True)

# %%
# drop Status column
df.drop('Status', axis=1,inplace=True)

# %%
df
# Out:
#        Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 9     20847.0           High      0.01        2.84           0.93
# 10    20228.0  Not Specified      0.02      500.98          26.00
# 11    21776.0       Critical      0.06        9.48           7.29
# 12    24844.0            NaN      0.09       78.69          19.99
# 13    24846.0            NaN      0.08        3.28           2.31
# ...       ...            ...       ...         ...            ...
# 1964  24014.0         Medium      0.04      300.98          54.92
# 1965  18495.0         Medium      0.09        2.88           1.49
# 1966  19074.0           High      0.03        4.26           1.20
# 1967  19950.0         Medium      0.01        4.91           0.50
# 1968  19951.0         Medium      0.09        4.00           1.30
#
#       Customer ID      Customer Name       Ship Mode Customer Segment  \
# 9             3.0      Bonnie Potter     Express Air        Corporate
# ...

# %%
df.duplicated().sum() # check number of duplicated values
# Out:
# 8

# %%
df.drop_duplicates(inplace=True) # drop duplicated

# %%
# check nulls again
df.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           5
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            2
# Ship Mode                6
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     16
# Country                  0
# Region                   0
# State or Province        5
# City                     6
# Postal Code              8
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# Manager                  0
# dtype: int64

# %%
# detect outlires
sns.boxplot(x='Product Base Margin', data=df,color='#87B8D6')
sns.stripplot(x='Product Base Margin', data=df, color="#172B44")
# then no outlires
# Out:
# <Axes: xlabel='Product Base Margin'>

# %%
# fill missing category columns by mode
fill_col = ['Order Priority','Customer Name','Ship Mode']
for col in fill_col:
    df[col].fillna(df[col].mode()[0],inplace=True)
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\2448525131.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0],inplace=True)

# %%
# fill missing category columns by mean
product_mean = df['Product Base Margin'].mean()
df['Product Base Margin'].fillna(product_mean, inplace=True)
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\163138437.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Product Base Margin'].fillna(product_mean, inplace=True)

# %%
df["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Regular Air       1437
# Delivery Truck     275
# Express Air        240
# Name: count, dtype: int64

# %%
df["Customer Name"].unique().tolist()
# Out:
# ['Bonnie Potter',
#  'Ronnie Proctor',
#  'Marcus Dunlap',
#  'Jenny Gold',
#  'Gwendolyn F Tyson',
#  'Timothy Reese',
#  'Sarah Ramsey',
#  'Laurie Hanna',
#  'Jim Rodgers',
#  'Tony Wilkins Winters',
#  'Edna Thomas',
#  'Guy Gallagher',
#  'Matthew Berman',
#  'Ricky Hensley',
#  'Theodore Moran',
#  'Lorraine Kelly',
#  'Sidney Russell Austin',
#  'Randall Montgomery',
#  'Pam Gilbert',
#  'Lynn Morrow',
#  'Ellen McCormick',
#  'Scott Bunn',
#  'Annette Boone',
#  'Edgar Stone',
#  'Helen Stein',
#  'Norman Shields',
#  'Wallace Werner',
#  'Victoria Baker Hoover',
#  'Eddie House Mueller',
#  'Max McKenna',
#  'Claudia Boyle',
#  'Caroline Johnston',
#  'Lois Hamilton',
#  'Tom McFarland',
#  'Ron Newton',
#  'Dwight M Carr',
#  'Linda Weiss',
#  'Helen H Murphy',
#  'Shawn Stern',
#  'Kara Allison',
#  'Dale Gillespie',
#  'Brooke Weeks Taylor',
#  'Marguerite Moss',
#  'Rhonda Ivey',
#  'Yvonne Fox',
#  'Geoffrey Zhu',
#  'Kent Kerr',
#  'Diana Xu',
# ...

# %%
df["Country"].value_counts()
# Out:
# Country
# United States    1952
# Name: count, dtype: int64

# %%
df["City"].unique().tolist() # missing values
# Out:
# ['Anacortes',
#  'San Gabriel',
#  'Roselle',
#  nan,
#  'Prior Lake',
#  'Smithtown',
#  'Syracuse',
#  'Missoula',
#  'New York City',
#  'Laguna Niguel',
#  'Lakewood',
#  'Grants Pass',
#  'Gresham',
#  'Redmond',
#  'Puyallup',
#  'Tonawanda',
#  'Round Rock',
#  'Salem',
#  'Napa',
#  'Burlington',
#  'Canton',
#  'Cincinnati',
#  'Vacaville',
#  'Vallejo',
#  'Terrytown',
#  'Chicago',
#  'Manhattan',
#  'Biddeford',
#  'Boston',
#  'Dover',
#  'Lodi',
#  'Lake Oswego',
#  'Mcminnville',
#  'Seattle',
#  'Layton',
#  'Tysons Corner',
#  'Alton',
#  'Petaluma',
#  'Ansonia',
#  'Yarmouth',
#  'West Mifflin',
#  'Watauga',
#  'Kingsport',
#  'Knoxville',
#  'Fort Collins',
#  'Richland',
#  'Lebanon',
#  'Baton Rouge',
#  'Fort Lee',
#  'San Francisco',
#  'Arlington',
#  'Gainesville',
#  'Arlington Heights',
#  'Aurora',
#  'Lehi',
#  'Overland Park',
#  'Detroit',
#  'Bartlesville',
#  'Troy',
#  'Utica',
#  'Murray',
#  'Mint Hill',
#  'Orland Park',
#  'Newton',
# ...

# %%
df["State or Province"].unique().tolist() # missing values
# Out:
# ['Washington',
#  'California',
#  'New Jersey',
#  nan,
#  'Minnesota',
#  'New York',
#  'Montana',
#  'Oregon',
#  'Texas',
#  'Virginia',
#  'Vermont',
#  'Ohio',
#  'Louisiana',
#  'Illinois',
#  'Kansas',
#  'Maine',
#  'Massachusetts',
#  'New Hampshire',
#  'Utah',
#  'Connecticut',
#  'Pennsylvania',
#  'Tennessee',
#  'Colorado',
#  'Michigan',
#  'Oklahoma',
#  'North Carolina',
#  'Iowa',
#  'Florida',
#  'New Mexico',
#  'Arizona',
#  'Georgia',
#  'Maryland',
#  'Rhode Island',
#  'Nebraska',
#  'Missouri',
#  'Nevada',
#  'Kentucky',
#  'West Virginia',
#  'Mississippi',
#  'Indiana',
#  'South Carolina',
#  'Arkansas',
#  'District of Columbia',
#  'Delaware',
#  'Alabama',
#  'Idaho',
#  'Wisconsin',
#  'South Dakota',
#  'Wyoming',
#  'North Dakota']

# %%
df["Postal Code"].unique().tolist() # missing values
# Out:
# [98221.0,
#  91776.0,
#  7203.0,
#  55372.0,
#  nan,
#  13210.0,
#  59601.0,
#  10012.0,
#  92677.0,
#  90712.0,
#  97526.0,
#  97030.0,
#  98052.0,
#  98373.0,
#  14150.0,
#  78664.0,
#  24153.0,
#  94559.0,
#  10177.0,
#  5401.0,
#  44708.0,
#  45231.0,
#  95687.0,
#  94591.0,
#  70056.0,
#  60601.0,
#  66502.0,
#  4005.0,
#  2129.0,
#  3820.0,
#  7644.0,
#  97035.0,
#  97128.0,
#  98103.0,
#  84041.0,
#  22102.0,
#  62002.0,
#  94952.0,
#  6401.0,
#  2664.0,
#  15122.0,
#  76148.0,
#  37664.0,
#  37918.0,
#  80525.0,
#  99352.0,
#  37087.0,
#  70802.0,
#  7024.0,
#  94122.0,
#  2474.0,
#  76240.0,
#  60004.0,
#  60505.0,
#  84043.0,
#  66212.0,
#  48138.0,
#  74006.0,
#  12180.0,
#  13501.0,
#  84107.0,
#  28227.0,
#  60462.0,
#  50208.0,
#  80027.0,
#  80817.0,
#  81503.0,
#  37804.0,
#  55423.0,
#  80126.0,
#  17331.0,
#  33772.0,
#  87505.0,
#  44106.0,
#  78207.0,
#  86001.0,
#  85234.0,
#  30297.0,
#  28204.0,
#  6824.0,
#  6111.0,
#  7109.0,
#  7101.0,
#  66203.0,
# ...

# %%
df["Region"].value_counts()
# Out:
# Region
# Central    566
# East       474
# West       470
# South      442
# Name: count, dtype: int64

# %%
df['Postal Code'].fillna("?", inplace=True) # fill missing values with '?'
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\16339433.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Postal Code'].fillna("?", inplace=True) # fill missing values with '?'
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\16339433.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '?' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
# ...

# %%
df[(df['Postal Code'] == '?')]['City'].unique() # finding the place of  errors tring to get the right values
# Out:
# array(['Prior Lake', 'Smithtown', 'Missoula', 'New York City',
#        'Laguna Niguel', nan], dtype=object)

# %%
df[(df['City'] =='Prior Lake' )]["Postal Code"].value_counts()
# Out:
# Postal Code
# 55372.0    6
# ?          1
# Name: count, dtype: int64

# %%
pl = df[(df['City'] =='Prior Lake' ) & (df['Postal Code'] == '?')].index
pl
# Out:
# Index([15], dtype='int64')

# %%
df['Postal Code'].iloc[pl]=df['Postal Code'].iloc[pl].apply(lambda x : '55372' if x == '?' else x) # fill with right postal code
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\2762666102.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
df[(df['City'] =='Smithtown' )]["Postal Code"].value_counts()
# Out:
# Postal Code
# ?    2
# Name: count, dtype: int64

# %%
sm = df[(df['City'] =='Smithtown' ) & (df['Postal Code'] == '?')].index
sm
# Out:
# Index([16, 17], dtype='int64')

# %%
# search on google about Smithtown postal code and found 11725
df['Postal Code'].iloc[sm]=df['Postal Code'].iloc[sm].apply(lambda x : '11725' if x == '?' else x) # fill with right postal code
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\2164202345.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
df[(df['City'] =='Missoula' )]["Postal Code"].value_counts()
# Out:
# Postal Code
# ?    1
# Name: count, dtype: int64

# %%
mi = df[(df['City'] =='Missoula' ) & (df['Postal Code'] == '?')].index
mi
# Out:
# Index([21], dtype='int64')

# %%
# search on google about Missoula postal code and found 11725
df['Postal Code'].iloc[mi]=df['Postal Code'].iloc[mi].apply(lambda x : '59801' if x == '?' else x) # fill with right postal code
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\245487384.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
df[(df['City'] =='New York City' )]["Postal Code"].value_counts()
# Out:
# Postal Code
# 10177.0    10
# 10004.0     6
# 10154.0     4
# 10039.0     4
# 10170.0     4
# 10009.0     3
# 10024.0     3
# 10011.0     2
# 10035.0     2
# 10165.0     2
# 10115.0     2
# ?           1
# 10012.0     1
# 10282.0     1
# 10112.0     1
# Name: count, dtype: int64

# %%
LA = df[(df['City'] =='Los Angeles' ) & (df['Postal Code'] == '?')].index
LA
# Out:
# Index([], dtype='int64')

# %%
df['Postal Code'].iloc[LA]=df['Postal Code'].iloc[LA].apply(lambda x : '10177' if x == '?' else x) # fill with right postal code
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\1805633382.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
df[(df['City'] =='Laguna Niguel' )]["Postal Code"].value_counts()
# Out:
# Postal Code
# 11725      1
# 92677.0    1
# Name: count, dtype: int64

# %%
# check nulls
df.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Country                 0
# Region                  0
# State or Province       5
# City                    6
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# Manager                 0
# dtype: int64

# %%
df['City'].fillna("?", inplace=True) # fill missing values with '?'
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\2081807066.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['City'].fillna("?", inplace=True) # fill missing values with '?'

# %%
df[(df['City'] == '?')]['Postal Code'].unique() # finding the place of  errors tring to get the right values
# Out:
# array([55372.0, 13210.0, 59601.0, 10012.0, '?'], dtype=object)

# %%
df[(df['Postal Code'] =='55372' )]["City"]
# Out:
# Series([], Name: City, dtype: object)

# %%
nf1 = df[(df['City'] =='?' ) & (df['Postal Code'] == '55372')].index
nf1
# Out:
# Index([], dtype='int64')

# %%
# city is Prior Lake
df.loc[nf1, 'City'] = df.loc[nf1, 'City'].apply(lambda x: 'Prior Lake' if x == '?' else x)

# %%
nf2 = df[(df['City'] =='?' ) & (df['Postal Code'] == '13210')].index
nf2
# Out:
# Index([], dtype='int64')

# %%
#city is Syracuse
df.loc[nf2, 'City'] = df.loc[nf2, 'City'].apply(lambda x: 'Syracuse' if x == '?' else x)

# %%
nf3 = df[(df['City'] =='?' ) & (df['Postal Code'] == '59601')].index
nf3
# Out:
# Index([], dtype='int64')

# %%
##city is Helena
df.loc[nf3, 'City'] = df.loc[nf3, 'City'].apply(lambda x: 'Helena' if x == '?' else x)

# %%
nf4 = df[(df['City'] =='?' ) & (df['Postal Code'] == '10012')].index
nf4
# Out:
# Index([], dtype='int64')

# %%
# New York City
df.loc[nf4, 'City'] = df.loc[nf4, 'City'].apply(lambda x: 'New York City' if x == '?' else x)

# %%
df['State or Province'].fillna("?", inplace=True) # fill missing values with '?'
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\99615779.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['State or Province'].fillna("?", inplace=True) # fill missing values with '?'

# %%
df["State or Province"].value_counts()
# Out:
# State or Province
# California              212
# New York                127
# Texas                   124
# Florida                 123
# Illinois                 88
# Ohio                     81
# Michigan                 66
# Washington               61
# Indiana                  53
# Pennsylvania             52
# Virginia                 51
# Minnesota                50
# North Carolina           49
# Massachusetts            46
# Colorado                 44
# Georgia                  44
# Tennessee                41
# Wisconsin                39
# Utah                     38
# Iowa                     38
# Maryland                 34
# New Jersey               32
# Arizona                  31
# South Carolina           30
# Oregon                   28
# Missouri                 27
# Maine                    27
# Kansas                   27
# Alabama                  22
# Arkansas                 22
# Kentucky                 22
# Idaho                    20
# ...

# %%
df[(df['State or Province'] =='?' ) & (df['Postal Code'])]
# Out:
#      Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 12  24844.0            Low      0.09       78.69          19.99         14.0
# 17  20925.0         Medium      0.01       35.94           6.66         15.0
# 18  26267.0            Low      0.04        2.98           1.58         16.0
# 25  20631.0           High      0.06       55.48          14.30         24.0
# 26  20632.0           High      0.02        1.68           1.57         24.0
#
#     Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 12     Jenny Gold  Regular Air   Small Business        Furniture  ...
# 17  Timothy Reese  Regular Air   Small Business  Office Supplies  ...
# 18   Sarah Ramsey  Regular Air   Small Business  Office Supplies  ...
# 25    Edna Thomas  Regular Air        Corporate  Office Supplies  ...
# 26    Edna Thomas  Regular Air        Corporate  Office Supplies  ...
#
#    State or Province           City Postal Code  Order Date   Ship Date  \
# ...

# %%
# clean postal code that city is Smithtown
nf5 = df[(df['Postal Code'] =='?' ) & (df['City'] == 'Smithtown')].index
nf5
# Out:
# Index([16, 17], dtype='int64')

# %%
# 11725
df.loc[nf5, 'Postal Code'] = df.loc[nf5, 'Postal Code'].apply(lambda x: '11725' if x == '?' else x)

# %%
df[(df['Postal Code'] =='?')]
# Out:
#      Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 15  24848.0         Medium      0.05        3.58           1.63         14.0
# 21  24063.0            Low      0.07       12.99           9.44         19.0
# 22   5890.0           High      0.05       26.48           6.93         21.0
# 28  23509.0           High      0.08       34.99           7.73         32.0
# 29  23612.0           High      0.01       17.98           8.51         32.0
#
#            Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 15            Jenny Gold  Regular Air   Small Business  Office Supplies  ...
# 21           Jim Rodgers  Regular Air   Small Business       Technology  ...
# 22  Tony Wilkins Winters  Regular Air   Small Business        Furniture  ...
# 28        Matthew Berman  Regular Air        Corporate  Office Supplies  ...
# 29        Matthew Berman  Regular Air        Corporate       Technology  ...
#
# ...

# %%
st1 = df[(df['State or Province'] =='Oregon' ) & (df['City'] == '?')].index

# %%
df.loc[st1, 'City'] = df.loc[st1, 'City'].apply(lambda x: 'Antelope' if x == '?' else x)

# %%
st2 = df[(df['City'] =='Antelope' ) & (df['Postal Code'] == '?')].index

# %%
df.loc[st2, 'Postal Code'] = df.loc[st2, 'Postal Code'].apply(lambda x: '95843' if x == '?' else x)

# %%
df[(df['Postal Code'] =='?')]
# Out:
#      Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 15  24848.0         Medium      0.05        3.58           1.63         14.0
# 21  24063.0            Low      0.07       12.99           9.44         19.0
# 22   5890.0           High      0.05       26.48           6.93         21.0
#
#            Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 15            Jenny Gold  Regular Air   Small Business  Office Supplies  ...
# 21           Jim Rodgers  Regular Air   Small Business       Technology  ...
# 22  Tony Wilkins Winters  Regular Air   Small Business        Furniture  ...
#
#    State or Province           City Postal Code  Order Date   Ship Date  \
# 15         Minnesota     Prior Lake           ?  2015-05-12  2015-05-13
# 21           Montana       Missoula           ?  2015-05-21  2015-05-23
# 22          New York  New York City           ?  2015-05-15  2015-05-16
#
# ...

# %%
df[(df['City'] =='?')]
# Out:
#      Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 12  24844.0            Low      0.09       78.69          19.99         14.0
# 19  26268.0           High      0.05      115.99           2.50         16.0
# 20  23890.0           High      0.05       26.48           6.93         18.0
# 23   6062.0  Not Specified      0.08        5.00           3.39         21.0
#
#            Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 12            Jenny Gold  Regular Air   Small Business        Furniture  ...
# 19          Sarah Ramsey  Regular Air   Small Business       Technology  ...
# 20          Laurie Hanna  Regular Air   Small Business        Furniture  ...
# 23  Tony Wilkins Winters  Regular Air   Small Business  Office Supplies  ...
#
#    State or Province City Postal Code  Order Date   Ship Date    Profit  \
# 12                 ?    ?     55372.0  2015-05-12  2015-05-14  803.4705
# ...

# %%
rf1 = df[(df['City'] =='?' ) & (df['Postal Code'] == '55372')].index

# %%
df.loc[rf1, 'City'] = df.loc[rf1, 'City'].apply(lambda x: 'Prior Lake' if x == '?' else x)

# %%
rf2 = df[(df['City'] =='?' ) & (df['Postal Code'] == '13210')].index

# %%
df.loc[rf2, 'City'] = df.loc[rf2, 'City'].apply(lambda x: 'Syracuse' if x == '?' else x)

# %%
rf3 = df[(df['City'] =='?' ) & (df['Postal Code'] == '59601')].index

# %%
df.loc[rf3, 'City'] = df.loc[rf3, 'City'].apply(lambda x: 'Helena' if x == '?' else x)

# %%
rf4 = df[(df['City'] =='?' ) & (df['Postal Code'] == '10012')].index

# %%
df.loc[rf4, 'City'] = df.loc[rf4, 'City'].apply(lambda x: 'New York City' if x == '?' else x)

# %%
df.loc[rf1, 'State or Province'] = df.loc[rf1, 'State or Province'].apply(lambda x: 'Minnesota' if x == '?' else x)

# %%
mg1 = df[(df['State or Province'] =='?' ) & (df['City'] == 'Smithtown')].index

# %%
df.loc[mg1, 'State or Province'] = df.loc[mg1, 'State or Province'].apply(lambda x: 'new york' if x == '?' else x)

# %%
mg2 = df[(df['State or Province'] =='?' ) & (df['City'] == 'Syracuse')].index

# %%
df.loc[mg2, 'State or Province'] = df.loc[mg2, 'State or Province'].apply(lambda x: 'new york' if x == '?' else x)

# %%
mg3 = df[(df['State or Province'] =='?' ) & (df['City'] == 'Laguna Niguel')].index

# %%
df.loc[mg3, 'State or Province'] = df.loc[mg3, 'State or Province'].apply(lambda x: 'california' if x == '?' else x)

# %%
mg4 = df[(df['State or Province'] =='?' ) & (df['Postal Code'] == '55372')].index

# %%
df.loc[mg4, 'State or Province'] = df.loc[mg4, 'State or Province'].apply(lambda x: 'Minnesota' if x == '?' else x)

# %%
df[(df['City'] =='?')]
# Out:
#      Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 12  24844.0            Low      0.09       78.69          19.99         14.0
# 19  26268.0           High      0.05      115.99           2.50         16.0
# 20  23890.0           High      0.05       26.48           6.93         18.0
# 23   6062.0  Not Specified      0.08        5.00           3.39         21.0
#
#            Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 12            Jenny Gold  Regular Air   Small Business        Furniture  ...
# 19          Sarah Ramsey  Regular Air   Small Business       Technology  ...
# 20          Laurie Hanna  Regular Air   Small Business        Furniture  ...
# 23  Tony Wilkins Winters  Regular Air   Small Business  Office Supplies  ...
#
#    State or Province City Postal Code  Order Date   Ship Date    Profit  \
# 12                 ?    ?     55372.0  2015-05-12  2015-05-14  803.4705
# ...

# %%
# i don't know why no changes, i will try another way

# %%
df.loc[12, 'City'] = 'Prior Lake'

# %%
df.loc[19, 'City'] = 'Syracuse'

# %%
df.loc[20, 'City'] = 'Helena'

# %%
df.loc[23, 'City'] = 'New York City'

# %%
df[(df['City'] =='?')]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Country, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, Manager]
# Index: []
#
# [0 rows x 26 columns]

# %%
df.loc[12, 'State or Province'] = 'Minnesota'

# %%
df[(df['State or Province'] =='?')]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Country, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, Manager]
# Index: []
#
# [0 rows x 26 columns]

# %%
# check nulls
df.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Country                 0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# Manager                 0
# dtype: int64

# %%
# check info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1952 entries, 9 to 1960
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   float64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   float64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1952 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %%
# check unique of dates
df['Order Date'].unique()
# Out:
# array(['2015-01-07', '2015-06-13', '2015-02-15', '2015-05-12',
#        '2015-04-08', '2015-05-28', '2015-02-12', '2015-05-15',
#        '2015-05-21', '2015-01-28', '2015-05-02', '2015-02-22',
#        '2015-03-27', '2015-01-20', '2015-03-12', '2015-06-15',
#        '2015-05-10', '2015-03-10', '2015-04-20', '2015-05-09',
#        '2015-06-12', '2015-03-02', '2015-01-02', '2015-02-02',
#        '2015-03-15', '2015-03-30', '2015-06-03', '2015-03-22',
#        '2015-05-17', '2015-02-18', '2015-03-04', '2015-06-07',
#        '2015-05-03', '2015-06-22', '2015-04-06', '2015-01-03',
#        '2015-04-04', '2015-04-09', '2015-01-12', '2015-01-27',
#        '2015-05-25', '2015-05-16', '2015-06-02', '2015-01-15',
#        '2015-03-16', '2015-04-23', '2015-01-22', '2015-04-19',
#        '2015-03-29', '2015-06-18', '2015-05-14', '2015-01-25',
#        '2015-01-11', '2015-04-13', '2015-02-21', '2015-05-22',
#        '2015-01-10', '2015-04-02', '2015-04-27', '2015-01-16',
# ...

# %%
# check unique of dates
df['Ship Date'].unique()
# Out:
# array(['2015-01-08', '2015-06-15', '2015-02-17', '2015-05-14',
#        '2015-05-13', '2015-04-09', '2015-05-28', '2015-02-15',
#        '2015-02-14', '2015-05-16', '2015-05-23', '2015-05-22',
#        '2015-01-29', '2015-01-30', '2015-05-04', '2015-02-23',
#        '2015-03-28', '2015-01-22', '2015-03-19', '2015-06-17',
#        '2015-06-16', '2015-05-11', '2015-03-10', '2015-03-11',
#        '2015-04-21', '2015-06-14', '2015-03-04', '2015-03-02',
#        '2015-01-09', '2015-01-02', '2015-01-04', '2015-02-04',
#        '2015-03-15', '2015-02-03', '2015-04-02', '2015-06-08',
#        '2015-03-23', '2015-03-25', '2015-05-18', '2015-02-20',
#        '2015-03-06', '2015-05-19', '2015-06-09', '2015-05-05',
#        '2015-06-24', '2015-04-07', '2015-06-23', '2015-04-06',
#        '2015-04-11', '2015-01-13', '2015-01-14', '2015-04-10',
#        '2015-01-28', '2015-05-26', '2015-05-17', '2015-06-03',
#        '2015-01-17', '2015-03-16', '2015-03-13', '2015-04-24',
# ...

# %%
# Convert data types
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df['Customer ID'] = df['Customer ID'].astype(str)
df['Order ID'] = df['Order ID'].astype(str)
df['Postal Code'] = df['Postal Code'].astype(str)

# %%
# generate new columns from date
df['Year']= df['Order Date'].dt.year
df['Month']= df['Order Date'].dt.month
df['Month_name']=df['Order Date'].dt.month_name()
df['week']= df['Order Date'].dt.isocalendar().week
df['Day']=df['Order Date'].dt.day
df['week_day']=df['Order Date'].dt.weekday
df['Day_name']=df['Order Date'].dt.day_name()

# %%
# Define seasons
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Fall'

# Add Season column
df['Season'] = df['Month'].apply(get_season)

# %%
# Define Quarter
def get_quarter(month):
    if month in [1, 2, 3]:
        return 'Q1'
    elif month in [4, 5, 6]:
        return 'Q2'
    elif month in [7, 8, 9]:
        return 'Q3'
    elif month in [10, 11, 12]:
        return 'Q4'
    else:
        return pd.nan

# Add quarter column
df['Quarter'] = df['Month'].apply(get_quarter)

# %%
# reset index after cleaning
df.reset_index()
# Out:
#       index   Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0         9  20847.0           High      0.01        2.84           0.93
# 1        10  20228.0  Not Specified      0.02      500.98          26.00
# 2        11  21776.0       Critical      0.06        9.48           7.29
# 3        12  24844.0            Low      0.09       78.69          19.99
# 4        13  24846.0            Low      0.08        3.28           2.31
# ...     ...      ...            ...       ...         ...            ...
# 1947   1956  19842.0           High      0.01       10.90           7.46
# 1948   1957  19843.0           High      0.10        7.99           5.03
# 1949   1958  26208.0  Not Specified      0.08       11.97           5.81
# 1950   1959  24911.0         Medium      0.10        9.38           4.93
# 1951   1960  25914.0           High      0.10      105.98          13.99
#
#      Customer ID      Customer Name       Ship Mode Customer Segment  ...  \
# ...

# %%
# Summary statistics
df.describe(include='number').T
# Out:
#                        count          mean          std        min      25%  \
# Row ID                1952.0  19916.479508  5957.595627       64.0  19121.0
# Discount              1952.0      0.048975     0.031378        0.0     0.02
# Unit Price            1952.0    109.079221   393.481301       1.14     6.48
# Shipping Cost         1952.0     12.968151    17.414631       0.49     3.23
# Product Base Margin   1952.0      0.515186     0.136492       0.35     0.38
# Profit                1952.0    114.793859  1141.112387 -16476.838 -84.4854
# Quantity ordered new  1952.0     12.944672    13.871565        1.0      5.0
# Sales                 1952.0    985.828832  2559.900167       2.25  58.8075
# Year                  1952.0        2015.0          0.0     2015.0   2015.0
# Month                 1952.0      3.415471     1.721819        1.0      2.0
# week                  1952.0     13.438525     7.518664        1.0      7.0
# ...

# %%
# cleaned data to csv
df.to_csv('cleaned_data.csv', index=False)

# %% [markdown]
# # Analysis

# %%
df.groupby("Year")['Sales'].sum().sort_values(ascending=False)
# Out:
# Year
# 2015    1924337.88
# Name: Sales, dtype: float64

# %%
df.groupby("Month_name")['Sales'].sum().sort_values(ascending=False)
# Out:
# Month_name
# April       389831.95
# June        355368.80
# February    326101.47
# May         306572.07
# January     274766.92
# March       271696.67
# Name: Sales, dtype: float64

# %%
sns.lineplot(data=df , x= 'Month', y='Sales',estimator=sum)
# Out:
# <Axes: xlabel='Month', ylabel='Sales'>

# %%
# What is The lowest 3 months ?
df.groupby("Month_name")['Sales'].sum().sort_values(ascending=True).head(3)
# Out:
# Month_name
# March      271696.67
# January    274766.92
# May        306572.07
# Name: Sales, dtype: float64

# %%
# what is the best season in sales ?
df.groupby('Season')['Sales'].sum().sort_values(ascending=False).head(1)
# Out:
# Season
# Spring    968100.69
# Name: Sales, dtype: float64

# %%
sns.set(rc={'figure.figsize':[11,7]},font_scale=1.2)
o=df.groupby('Season')['Sales'].sum().sort_values(ascending=False).index
sns.barplot(data=df , x= "Season", y='Sales',order=o,estimator=sum)
# Out:
# <Axes: xlabel='Season', ylabel='Sales'>

# %%
df.groupby('Day')['Sales'].sum().sort_values(ascending=False)
# Out:
# Day
# 21    127269.92
# 20    124589.29
# 5     113236.04
# 4     111750.08
# 2      94007.85
# 14     89849.66
# 25     81988.64
# 18     71065.65
# 6      67413.22
# 22     64263.26
# 11     61603.43
# 30     58531.65
# 12     58518.93
# 23     57964.33
# 28     57931.99
# 7      57252.30
# 29     57116.40
# 16     56755.06
# 10     52504.58
# 3      51376.61
# 26     46801.24
# 1      44363.00
# 24     44302.65
# 9      41907.43
# 15     40560.79
# 13     38744.43
# 17     38161.32
# 19     37679.61
# 27     29748.97
# 8      29533.13
# 31     17546.42
# Name: Sales, dtype: float64

# %%
o= df.groupby('Day')['Sales'].sum().sort_values(ascending=False).index
sns.barplot(data= df, x= 'Day', y= 'Sales', order=o, estimator=sum)
# Out:
# <Axes: xlabel='Day', ylabel='Sales'>

# %%
# sales count distribution by day
df['Day'].value_counts()
# Out:
# Day
# 4     84
# 20    84
# 5     81
# 6     80
# 12    76
# 15    74
# 28    73
# 14    72
# 17    71
# 21    71
# 22    70
# 2     68
# 25    68
# 11    67
# 7     64
# 1     63
# 30    62
# 9     62
# 16    62
# 10    61
# 24    61
# 27    60
# 26    59
# 18    55
# 23    55
# 19    55
# 13    46
# 3     46
# 29    46
# 8     39
# 31    17
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='Day')
# Out:
# <Axes: xlabel='Day', ylabel='count'>

# %%
# Top 10 Cities in sales
df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# City
# Los Angeles      154806.11
# New York City    145010.54
# Washington        68946.66
# Boston            49654.82
# Seattle           38437.77
# Detroit           29451.26
# Philadelphia      28442.95
# Chicago           22958.00
# Madison           20974.45
# Miami             19266.40
# Name: Sales, dtype: float64

# %%
sns.set(rc={'figure.figsize':[25,6]},font_scale=1.5)
o=df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(10).index
sns.barplot(data=df, x= "City", y="Sales",order=o,estimator=sum)
# Out:
# <Axes: xlabel='City', ylabel='Sales'>

# %%
# lowest 10 cities in sales
o=df.groupby('City')['Sales'].sum().sort_values(ascending=True).head(10).index
sns.barplot(data=df, x= "City", y="Sales",order=o,estimator=sum)
# Out:
# <Axes: xlabel='City', ylabel='Sales'>

# %%
#Top 10 states in sales
o=df.groupby('State or Province')['Sales'].sum().sort_values(ascending=False).head(10).index
sns.barplot(data=df, x= "State or Province", y="Sales",order=o,estimator=sum)
# Out:
# <Axes: xlabel='State or Province', ylabel='Sales'>

# %%
# Lowest 10 states in sales
o=df.groupby('State or Province')['Sales'].sum().sort_values(ascending=True).head(10).index
sns.barplot(data=df, x= "State or Province", y="Sales",order=o,estimator=sum)
# Out:
# <Axes: xlabel='State or Province', ylabel='Sales'>

# %%
# Total sales and profit by region
region_sales_profit = df.groupby('Region')[['Sales', 'Profit']].sum().reset_index().sort_values(by='Sales',ascending=False)
region_sales_profit
# Out:
#     Region      Sales        Profit
# 1     East  592171.49  85291.403446
# 3     West  526776.57  75844.790102
# 0  Central  448284.70  77365.472669
# 2    South  357105.12 -14424.054379

# %%
# Total sales and profit by product category
category_sales_profit = df.groupby('Product Category')[['Sales', 'Profit']].sum().reset_index().sort_values(by='Sales',ascending=False)
category_sales_profit
# Out:
#   Product Category      Sales        Profit
# 2       Technology  712264.95  75303.156364
# 0        Furniture  660704.31  59249.445936
# 1  Office Supplies  551368.62  89525.009537

# %%
# Calculate Recency (days since last order)
df['Recency'] = (datetime.now() - df['Order Date']).dt.days
df['Recency'].value_counts()
# Out:
# Recency
# 3568    28
# 3632    22
# 3650    22
# 3573    22
# 3661    22
#         ..
# 3628     3
# 3577     3
# 3599     3
# 3508     3
# 3605     2
# Name: count, Length: 179, dtype: int64

# %%
# loyal clustering
loyal_customer = df.groupby(['Customer ID','Customer Name'])['Recency'].max().reset_index().sort_values(by='Recency',ascending=False)
loyal_customer
# Out:
#     Customer ID            Customer Name  Recency
# 324      1910.0          Sean Stephenson     3666
# 155      1425.0            Gregory Crane     3666
# 401      2124.0             Paige Powers     3666
# 434      2211.0               Anita Hahn     3666
# 196      1552.0                Gary Koch     3666
# ..          ...                      ...      ...
# 115      1307.0              Teresa Hill     3486
# 387      2089.0               Annie Odom     3486
# 695      2885.0             Gary Frazier     3486
# 774      3119.0              Jay Hubbard     3486
# 455      2276.0  Dennis Block Richardson     3486
#
# [1131 rows x 3 columns]

# %%
# Calculate Frequency (number of orders per customer)
frequency_df = df.groupby(['Customer ID','Customer Name'])['Order ID'].nunique().reset_index().sort_values(by='Order ID',ascending=False)

# %%
# rename order id to frequency
frequency_df.columns = ['Customer ID','Customer Name','Frequency']
frequency_df
# Out:
#      Customer ID     Customer Name  Frequency
# 793       3151.0     Glenda Hunter          6
# 692       2882.0   Andrew Gonzalez          6
# 1027       699.0        Jenny Gold          5
# 52        1129.0        Pam Patton          5
# 540       2491.0      Sean N Boyer          5
# ...          ...               ...        ...
# 439       2225.0      Sean McKenna          1
# 440       2240.0     Maurice Kelly          1
# 441       2250.0      Alvin Hoover          1
# 444       2257.0  Bernard Thompson          1
# 1130       999.0       Rita Barton          1
#
# [1131 rows x 3 columns]

# %%
# Calculate Monetary (total sales per customer)
customerSales_df = df.groupby(['Customer ID','Customer Name'])['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)
customerSales_df
# Out:
#      Customer ID       Customer Name     Sales
# 962        553.0   Kristine Connolly  50475.31
# 265       1733.0    Nina Horne Kelly  48295.12
# 941        491.0        Toni Swanson  32194.12
# 576       2571.0    Rosemary O'Brien  29916.01
# 612       2670.0         Yvonne Mann  28779.13
# ...          ...                 ...       ...
# 234       1665.0       Elsie Pridgen      6.97
# 1064       820.0   Catherine Mullins      5.90
# 522       2450.0        Tonya Miller      4.21
# 1117       960.0    Phillip Chappell      3.51
# 253        171.0  Christina Matthews      3.42
#
# [1131 rows x 3 columns]

# %%
# Group by Month and calculate total sales
monthly_sales = df.groupby(['Year', 'Month', 'Month_name'])['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)
monthly_sales
# Out:
#    Year  Month Month_name      Sales
# 3  2015      4      April  389831.95
# 5  2015      6       June  355368.80
# 1  2015      2   February  326101.47
# 4  2015      5        May  306572.07
# 0  2015      1    January  274766.92
# 2  2015      3      March  271696.67

# %%
# Group by Week and calculate total sales
weekly_sales = df.groupby(['Year', 'week'])['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)
weekly_sales
# Out:
#     Year  week      Sales
# 13  2015    14  123791.87
# 7   2015     8  122345.07
# 16  2015    17  111612.29
# 11  2015    12   96152.62
# 22  2015    23   95482.93
# 6   2015     7   93846.61
# 23  2015    24   91096.40
# 17  2015    18   90822.96
# 20  2015    21   85952.70
# 24  2015    25   84466.27
# 1   2015     2   82026.90
# 14  2015    15   70980.93
# 21  2015    22   69396.30
# 5   2015     6   66250.39
# 4   2015     5   59606.35
# 25  2015    26   56406.20
# 18  2015    19   55440.09
# 10  2015    11   55351.75
# 19  2015    20   54153.04
# 3   2015     4   51573.67
# 8   2015     9   50269.34
# 15  2015    16   49531.25
# 0   2015     1   48784.98
# 12  2015    13   45993.00
# 9   2015    10   44782.92
# 2   2015     3   40304.05
# 26  2015    27   27917.00

# %%
# Group by Day of Week and calculate total sales
daily_sales = df.groupby(['Day_name', 'week_day'])['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)
daily_sales
# Out:
#     Day_name  week_day      Sales
# 2   Saturday         5  456846.03
# 0     Friday         4  299751.29
# 1     Monday         0  251227.65
# 4   Thursday         3  240694.20
# 5    Tuesday         1  233603.06
# 6  Wednesday         2  223024.10
# 3     Sunday         6  219191.55

# %%
# Group by season and calculate total sales
season_sales = df.groupby(['Year', 'Season'])['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)
season_sales
# no sales in 9,10,11 months
# Out:
#    Year  Season      Sales
# 0  2015  Spring  968100.69
# 2  2015  Winter  600868.39
# 1  2015  Summer  355368.80

# %%
# Group by season and calculate total sales
quarter_sales = df.groupby(['Quarter'])['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)
quarter_sales
# no sales in Q3,Q4
# Out:
#   Quarter       Sales
# 1      Q2  1051772.82
# 0      Q1   872565.06

# %%
# columns of final data
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID', 'Manager',
#        'Year', 'Month', 'Month_name', 'week', 'Day', 'week_day', 'Day_name',
#        'Season', 'Quarter', 'Recency'],
#       dtype='object')

# %%
# calculate all totals to using it in cards in deployment and conclusion
Total_sales = df['Sales'].sum()
Total_profit = df['Profit'].sum()
Total_discount = df['Discount'].sum()
Total_cost = df['Shipping Cost'].sum()
Quantity = df['Quantity ordered new'].sum()
NOfCustomers = df['Customer ID'].nunique()
NOfCategories = df['Product Category'].nunique()
NOfSubCategories = df['Product Sub-Category'].nunique()
NOfCountries = df['Country'].nunique()
NOfOrders = df['Order ID'].nunique()

# %% [markdown]
# # Visualization
# ##### by seaborn and deployment by plotly

# %% [markdown]
# ### Bi/multi-variate

# %%
# Top 10 Products by Sales
top_sales = df.groupby('Product Name')['Sales'].sum().reset_index().sort_values('Sales', ascending=False).head(10)
# Bar plot
sns.barplot(x='Sales', y='Product Name', data=top_sales, palette='viridis')
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\2432525890.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Sales', y='Product Name', data=top_sales, palette='viridis')
# <Axes: xlabel='Sales', ylabel='Product Name'>

# %%
# Top 10 Products by Unit Price
top_price = df.groupby('Product Name')['Unit Price'].mean().reset_index().sort_values('Unit Price', ascending=False).head(10)
sns.barplot(x='Unit Price', y='Product Name', data=top_price, palette='coolwarm')
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\1791985949.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Unit Price', y='Product Name', data=top_price, palette='coolwarm')
# <Axes: xlabel='Unit Price', ylabel='Product Name'>

# %%
# Top 10 Products by Product Base Margin
top_margin = df.groupby('Product Name')['Product Base Margin'].mean().reset_index().sort_values('Product Base Margin', ascending=False).head(10)
sns.barplot(x='Product Base Margin', y='Product Name', data=top_margin, palette='magma')
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\2793295932.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Product Base Margin', y='Product Name', data=top_margin, palette='magma')
# <Axes: xlabel='Product Base Margin', ylabel='Product Name'>

# %%
# Sales and Profit by Region
sns.barplot(x='Region', y='Sales', data=region_sales_profit, palette='Accent')
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\2684387530.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Region', y='Sales', data=region_sales_profit, palette='Accent')
# <Axes: xlabel='Region', ylabel='Sales'>

# %%
# Example: Line plot of 'Sales' over 'Month'
sns.lineplot(x='Month', y='Sales', data=df, hue='Year', palette='Set2')
# Out:
# <Axes: xlabel='Month', ylabel='Sales'>

# %%
sns.countplot(x='Region', hue='Profit', data=region_sales_profit,palette='Accent')
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
# Sales and Profit by Product Category
sns.barplot(x='Product Category', y='Sales', data=category_sales_profit, palette='Accent')
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\4146198523.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Product Category', y='Sales', data=category_sales_profit, palette='Accent')
# <Axes: xlabel='Product Category', ylabel='Sales'>

# %%
# correlation btw month,sales
corr_matrix = df[['Month', 'Sales']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
# each product category and profit
sns.barplot(x='Product Category', y='Profit', data=category_sales_profit, palette='Accent')
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\1049323190.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Product Category', y='Profit', data=category_sales_profit, palette='Accent')
# <Axes: xlabel='Product Category', ylabel='Profit'>

# %%
# Calculate correlation matrix
corr_matrix = df[['Sales', 'Unit Price', 'Product Base Margin']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
# Shipping cost by ship mode
shipping_cost = df.groupby('Ship Mode')['Shipping Cost'].mean().reset_index()
sns.barplot(x='Ship Mode', y='Shipping Cost', data=shipping_cost,palette='Accent')
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\2726721142.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Ship Mode', y='Shipping Cost', data=shipping_cost,palette='Accent')
# <Axes: xlabel='Ship Mode', ylabel='Shipping Cost'>

# %%
# Pair plot of Sales, Price, and Margin
sns.pairplot(df[['Sales', 'Unit Price', 'Product Base Margin']], palette='Set1')
# Out:
# C:\Users\Mohamed Koura\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\Mohamed Koura\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\Mohamed Koura\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\Mohamed Koura\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# C:\Users\Mohamed Koura\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# ...

# %%
# count of each region
region_counts = df['Region'].value_counts()
sns.barplot(x=region_counts.index, y=region_counts.values, palette='Accent')
# Out:
# C:\Users\Mohamed Koura\AppData\Local\Temp\ipykernel_7796\1831350777.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=region_counts.index, y=region_counts.values, palette='Accent')
# <Axes: xlabel='Region'>

# %% [markdown]
# ### Univariate

# %%
sns.kdeplot(data= df, x= 'Sales')
# Out:
# <Axes: xlabel='Sales', ylabel='Density'>

# %%
# hist plot of managers
sns.histplot(df['Manager'], kde=True, bins=30,color='#4C4E43')
# Out:
# <Axes: xlabel='Manager', ylabel='Count'>

# %%
#  customer segment
sns.boxplot(y=df['Customer Segment'],color='pink')
# Out:
# <Axes: ylabel='Customer Segment'>

# %%
# hist plot profit
sns.histplot(df['Profit'], kde=True, bins=30, color='#DABB8D')
# Out:
# <Axes: xlabel='Profit', ylabel='Count'>

# %%
# Distribution of Sales
sns.histplot(df['Sales'], kde=True, color='blue')
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %% [markdown]
# # Conclusion

# %% [markdown]
# ##### Revenue: 1.9 M
# ##### Profit: 227.832 K
# ##### Cost: 25.434 K
# ##### N Of Customers: 1130
# ##### N Of Managers: 4
# ##### N Of Orders: 1365
# ##### N Of Categories: 3
# ##### N Of Sub-Category: 17
# ##### N Of Countries: 1
# ##### N Of Regions: 4
# ##### N Of Cities: 868
# ##### N Of States: 49

# %% [markdown]
# #### Recommenditions to increase business performance, you can leverage insights from your dataset (e.g., sales, customer, and product data) to make data-driven decisions.

# %% [markdown]
# ##### 1. Focus on High-Value Customers
#
# Identify High-Value Customers:
# Use (Recency, Frequency, Monetary) analysis to segment customers based on their purchasing behavior.
# Focus on customers with high monetary value and frequent purchases.
#
# Personalized Marketing:
# Offer personalized discounts, loyalty programs, or exclusive deals to retain high-value customers.
#
# Upselling and Cross-Selling:
# Recommend complementary products or premium versions to increase average order value.

# %% [markdown]
# ##### 2. Optimize Product Offerings
#
# Top-Performing Products:
# Identify top-selling and high-margin products using sales and profit analysis.
# Increase stock and marketing efforts for these products.
#
# Underperforming Products:
# Analyze low-performing products and consider discontinuing or discounting them.
#
# Product Bundling:
# Bundle complementary products to increase sales volume.

# %% [markdown]
# ##### 3. Improve Customer Experience
#
# Shipping and Delivery:
# Analyze shipping costs and delivery times by region and ship mode.
# Optimize shipping methods to reduce costs and improve delivery speed.
#
# Customer Feedback:
# Collect and analyze customer feedback to identify pain points and areas for improvement.
#
# Easy Returns:
# Simplify the return process to enhance customer satisfaction.

# %% [markdown]
# ##### 4. Regional Performance Analysis
#
# Top-Performing Regions:
# Identify regions with the highest sales and profit margins.
# Increase marketing and inventory in these regions.
#
# Underperforming Regions:
# Investigate reasons for low performance (e.g., lack of awareness, high shipping costs).
# Run targeted promotions or campaigns to boost sales.

# %% [markdown]
# ##### 5. Discount and Pricing Strategy
#
# Discount Optimization
#
# Analyze the impact of discounts on sales and profit margis.
#
# Offer strategic discounts on slow-moving or high-margin products.
#
# Dynamic Picing:
#
# Implement dynamic pricing strategies based on demand, seasonality, and competitorricing.

# %% [markdown]
# ##### 6. Enhance Marketing Campaigns
#
# Targeted Campaigns:
# Use customer segmentation to create targeted marketing campaigns.
# Focus on specific customer segments (e.g., high-value customers, new customers).
#
# Seasonal Promotions:
# Run promotions during peak seasons or holidays to boost sales.
#
# Digital Marketing:
# Invest in social media, email marketing, and search engine optimization (SEO) to reach a wider audience.

# %% [markdown]
# ##### 7. Focus on Q3 and Q4 in year because there is no sales specially in 7,8,9,10,11 Months

# %%
# get current directory
import os
os.getcwd()
# Out:
# 'C:\\Users\\Mohamed Koura'

# %%
# %mkdir final_proj
# %cd final_proj
# Out:
# C:\Users\Mohamed Koura\final_proj
# A subdirectory or file final_proj already exists.

# %% [markdown]
# # Deployment

# %%
# %%writefile homepage.py
import streamlit as st
import plotly.express as px
import plotly.figure_factory as ff
import pandas as pd

#page configration
st.set_page_config(
    layout='wide',
    page_title='HomePage',
    page_icon='🛒'
)

#Side bar
x = st.sidebar.checkbox('Show Data',False,key=1)
# Custom colored message in the sidebar
st.sidebar.markdown(
    """
    <div style="background-color: #57B7F2; padding: 10px; border-radius: 5px; text-align: center; color: white;">
        <strong>Please select a page above!</strong>
    </div>
    """,
    unsafe_allow_html=True
)

#load data
df = pd.read_csv(r"D:\data course\epsilion\Mohamed Osama Rashed\cleaned_data.csv")

# Main page title
st.markdown('<h1 style="text-align: center; color: black;">Home Page For Dashboard</h1>', unsafe_allow_html=True)
st.write("""
Welcome to the Home Page of the Dashboard! This dashboard is designed to provide insights and visualizations 
based on E-Commerce Data. You can explore the data by checking the 'Show Data' checkbox in the sidebar. 
This will display the dataset in a tabular format. Stay tuned for more features and visualizations!
""")

if x:
    st.dataframe(df.copy(), height=500, width=1000)

st.markdown('<h2 style="text-align: center; color: black;">Conclusion</h2>', unsafe_allow_html=True)
# data metric for the table
summary_data = {
    "Metric": ["Revenue", "Profit", "Cost", "Customers", "Managers", "Orders", "Categories", "Sub-Categories", "Countries", "Regions", "Cities", "States"],
    "Value": ["1.9 M$", "227.832 K$", "25.434 K$", 1130, 4, 1365, 3, 17, 1, 4, 868, 49]
}

# Convert data to a DataFrame
summary_df = pd.DataFrame(summary_data)

# Create a table using plotly.figure_factory
table = ff.create_table(summary_df)

# Display the table in Streamlit
st.plotly_chart(table, use_container_width=True)

# recommenditions
st.markdown('<h2 style="text-align: center; color: black;">Recommenditions to increase business performance, you can leverage insights from your dataset (e.g., sales, customer, and product data) to make data-driven decisions</h2>', unsafe_allow_html=True)
st.write(""" 
**1. Focus on High-Value Customers**
   
- Identify High-Value Customers:
Use (Recency, Frequency, Monetary) analysis to segment customers based on their purchasing behavior.
Focus on customers with high monetary value and frequent purchases.
- Personalized Marketing:
Offer personalized discounts, loyalty programs, or exclusive deals to retain high-value customers.
- Upselling and Cross-Selling:
Recommend complementary products or premium versions to increase average order value.
""")
st.write(""" 
**2. Optimize Product Offerings**

- Top-Performing Products:
Identify top-selling and high-margin products using sales and profit analysis.
Increase stock and marketing efforts for these products.
- Underperforming Products:
Analyze low-performing products and consider discontinuing or discounting them.
- Product Bundling:
Bundle complementary products to increase sales volume.
""")
st.write(""" 
**3. Improve Customer Experience**

- Shipping and Delivery:
Analyze shipping costs and delivery times by region and ship mode.
Optimize shipping methods to reduce costs and improve delivery speed.
- Customer Feedback:
Collect and analyze customer feedback to identify pain points and areas for improvement.
- Easy Returns:
Simplify the return process to enhance customer satisfaction.
""")
st.write(""" 
**4. Regional Performance Analysis**

- Top-Performing Regions:
Identify regions with the highest sales and profit margins.
Increase marketing and inventory in these regions.
- Underperforming Regions:
Investigate reasons for low performance (e.g., lack of awareness, high shipping costs).
Run targeted promotions or campaigns to boost sales.
""")
st.write(""" 
**5. Discount and Pricing Strategy**

- Discount Optimization
- Analyze the impact of discounts on sales and profit margis.
- Offer strategic discounts on slow-moving or high-margin products.
- Dynamic Picing:
- Implement dynamic pricing strategies based on demand, seasonality, and competitorricing.
""")
st.write(""" 
**6. Enhance Marketing Campaigns**

- Targeted Campaigns:
Use customer segmentation to create targeted marketing campaigns.
Focus on specific customer segments (e.g., high-value customers, new customers).
- Seasonal Promotions:
Run promotions during peak seasons or holidays to boost sales.
- Digital Marketing:
Invest in social media, email marketing, and search engine optimization (SEO) to reach a wider audience.
""")
st.write(""" 
**7. Sales and Unit Price Relationship**

- There appears to be a relationship between sales and unit price.
As the unit price increases, sales seem to fluctuate, but there is no clear linear trend.
This suggests that other factors might be influencing sales beyond just price.
""")
st.write(""" 
**8. Product Base Margin**

- The product base margin varies between 0.4 and 0.8. This indicates that the profitability of the products can differ significantly.
Products with higher margins are likely more profitable, assuming costs remain constant.
""") 
st.write(""" 
**9. Sales Volume**

- Sales volumes range from 0 to 45k units. The highest sales volume is 45k,
which could indicate a peak period or a particularly popular product.
""")
st.write(""" 
**10. Unit Price Range**

- The unit price ranges from 0 to 6000. 
This wide range suggests that the products vary significantly in terms of pricing,
which could be due to differences in product features, quality, or market positioning.
""") 
st.write(""" 
**11. Potential Outliers**

- There are some data points that stand out, such as the highest sales volume (45k) and the highest unit price (6000).
These could be outliers or represent special cases that warrant further investigation.
""") 
st.write(""" 
**12. Profitability Analysis**

- Combining sales volume, unit price, and product base margin could provide insights into overall profitability.
Products with higher margins and higher sales volumes are likely the most profitable.
""") 
st.write(""" 
**13. Focus on Q3 and Q4 in year because there is no sales specially in 7,8,9,10,11 Months.**
""")
# Out:
# Overwriting homepage.py

# %%
# %mkdir pages
# %cd pages
# Out:
# C:\Users\Mohamed Koura\final_proj\pages
# A subdirectory or file pages already exists.

# %%
# %%writefile Customers.py
import streamlit as st
import plotly.express as px
import plotly.figure_factory as ff
import pandas as pd


st.set_page_config(
        layout = 'wide',
        page_title = 'Customers',
        page_icon= '👫'
)

# Set colors and page configuration
color1 = ['#012340','#57B7F2','#0487D9','#F29F05','#F2E0DF']
#load data
df = pd.read_csv(r"D:\data course\epsilion\Mohamed Osama Rashed\cleaned_data.csv")

st.markdown('<h2 style="text-align: center; color: black;">Customers Sales and Profits</h2>', unsafe_allow_html=True)
col= st.selectbox('select feature to see its distribution', ['Sales', 'Profit'], key=10)
with st.container():
    df_top5 = df.nlargest(5, col)
    fig= px.histogram(df_top5, x= 'Customer Name',y=col, color_discrete_sequence=color1)
    st.plotly_chart(fig, use_container_width= True)

st.markdown('<h2 style="text-align: center; color: black;">Customers Location</h2>', unsafe_allow_html=True)
col= st.selectbox('select feature to see where Most customers from',['Region', 'City', 'State or Province', 'Country'])
with st.container():

   # Group the data by the selected feature and count the number of customers
   df_grouped = df[col].value_counts().reset_index()
   df_grouped.columns = [col, 'Count']

   # Filter the grouped data to include only the top 5 rows
   df_top5 = df_grouped.head(5)

   # Create the pie chart
   fig = px.pie(df_top5, names=col, values='Count',color_discrete_sequence=color1,hole=0.3).update_traces(
       textinfo='value+percent',  # Display both values and percentages on the chart
       pull=[0.1, 0, 0, 0, 0]     # Pull the first slice for emphasis
   )

# Display the pie chart in Streamlit
st.plotly_chart(fig, use_container_width=True)

st.markdown('<h2 style="text-align: center; color: black;">Customers Segment</h2>', unsafe_allow_html=True)

df_grouped = df['Customer Segment'].value_counts().reset_index()
df_grouped.columns = ['Customer Segment', 'Count']
fig = px.scatter(df_grouped,x='Customer Segment',y='Count',marginal_x='histogram',marginal_y='violin')
st.plotly_chart(fig, use_container_width=True)

st.markdown('<h2 style="text-align: center; color: black;">Customers Managers</h2>', unsafe_allow_html=True)
df_grouped = df['Manager'].value_counts().reset_index()
df_grouped.columns = ['Manager', 'Count']

# Filter the grouped data to include only the top 5 rows
df_top5 = df_grouped.head(5)

fig= px.histogram(df_top5, x= 'Manager',y='Count', color_discrete_sequence=color1)
st.plotly_chart(fig, use_container_width=True)
# Out:
# Overwriting Customers.py

# %%
# %%writefile Products.py
import streamlit as st
import plotly.express as px
import pandas as pd


st.set_page_config(
        layout = 'wide',
        page_title = 'Customers',
        page_icon= '🏷️'
)

# Set colors and page configuration
color1 = ['#012340','#57B7F2','#0487D9','#F29F05','#F2E0DF']
#load data
df = pd.read_csv(r"D:\data course\epsilion\Mohamed Osama Rashed\cleaned_data.csv")

st.markdown('<h2 style="text-align: center; color: black;">Product Category</h2>', unsafe_allow_html=True)
col = st.radio('select feature to see its distribution', ['Unit Price','Discount','Product Base Margin'], key=3, horizontal=True)
# Group the data by Product Category and calculate the sum of the selected feature
df_grouped = df.groupby('Product Category')[col].sum().reset_index()

# Filter the grouped data to include only the top 3 rows
df_top5 = df_grouped.nlargest(3, col)

# Create the line chart
fig = px.line(
    df_top5, 
    x='Product Category',  # X-axis: Product Category
    y=col,                 # Y-axis: Selected feature (Unit Price, Discount, or Product Base Margin)
    title=f'Top 3 Product Categories by {col}',  # Chart title
    labels={col: f'Sum of {col}'}  # Label for the y-axis
).update_traces(
    line=dict(color=color1[1]),  # Use the second color in the custom color sequence
    mode='lines+markers'         # Add markers to the line
)
# Display the line chart in Streamlit
st.plotly_chart(fig, use_container_width=True)


# Streamlit selectbox to choose a feature
col = st.selectbox('Select feature to see its distribution', ['Sales', 'Profit'])
# Group the data by Product Categories and calculate the sum of the selected feature
top_sales = df.groupby('Product Category')[col].sum().reset_index()

# Filter the grouped data to include only the top 3 rows
df_top3 = top_sales.nlargest(3, col)

# Create the pie chart
fig = px.pie(
    df_top3, 
    names='Product Category',  # Labels for the pie chart slices
    values=col,                  # Numeric values for the pie chart slices
    color_discrete_sequence=color1,  # Custom color sequence
    hole=0.3                     # Add a hole in the middle for a donut chart
).update_traces(
    textinfo='value+percent',    # Display both values and percentages on the chart
    pull=[0.1, 0, 0]             # Pull the first slice for emphasis
)

# Display the pie chart in Streamlit
st.plotly_chart(fig, use_container_width=True)


st.markdown('<h2 style="text-align: center; color: black;">Product Name</h2>', unsafe_allow_html=True)

# Streamlit selectbox to choose a feature
col = st.selectbox('Select feature to see its distribution', ['Sales', 'Profit'],key='feature_selectbox')

# Group the data by Product Name and calculate the sum of the selected feature
top_sales = df.groupby('Product Name')[col].sum().reset_index()

# Filter the grouped data to include only the top 5 rows
df_top5 = top_sales.nlargest(5, col)

# Create the bar chart
fig = px.bar(
    df_top5, 
    x='Product Name',  # X-axis: Product Name
    y=col,             # Y-axis: Selected feature (Sales or Profit)
    color_discrete_sequence=color1,  # Custom color sequence
    labels={col: f'Total {col}'},    # Label for the y-axis
    title=f'Top 5 Products by {col}'  # Chart title
)

# Display the bar chart in Streamlit
st.plotly_chart(fig, use_container_width=True)


col = st.selectbox('Select feature to see its distribution', ['Discount','Unit Price','Product Base Margin'])
top_price = df.groupby(['Product Name','Product Category'])[col].sum().reset_index()
# Filter the grouped data to include only the top 5 rows
df_top5 = top_price.nlargest(5, col)
fig = px.bar(df_top5, x="Product Name", y=col, 
             color='Product Category',color_discrete_sequence=color1,
             labels={col: f'Total {col}'},
             title=f'Top 5 Products by {col}'
             )

# Display the bar chart in Streamlit
st.plotly_chart(fig, use_container_width=True)

# Select the columns for the pair plot
columns = ['Sales', 'Unit Price', 'Product Base Margin']

# Create a Plotly scatter matrix (similar to Seaborn pairplot)
fig = px.scatter_matrix(
    df,
    dimensions=columns,  # Columns to include in the pair plot
    title="Pair Plot of Sales, Unit Price, and Product Base Margin",  # Title of the plot
    color=columns[0],  # Color points by the first column (e.g., 'Sales')
    opacity=0.7,  # Set opacity for better visibility
    labels={col: col.replace('_', ' ') for col in columns}  # Format axis labels
)

# Update layout for better readability
fig.update_layout(
    width=1000,  # Set width of the plot
    height=800,  # Set height of the plot
    showlegend=True  # Show legend
)

# Display the Plotly figure in Streamlit
st.plotly_chart(fig, use_container_width=True)
# Out:
# Overwriting Products.py

# %%
# %%writefile Time_Geography.py
import streamlit as st
import plotly.express as px
import pandas as pd


st.set_page_config(
        layout = 'wide',
        page_title = 'Time',
        page_icon= '⌛'
)

# Set colors and page configuration
color1 = ['#012340','#57B7F2','#0487D9','#F29F05','#F2E0DF']
#load data
df = pd.read_csv(r"D:\data course\epsilion\Mohamed Osama Rashed\cleaned_data.csv")

tab1, tab2 = st.tabs(['🕑 Time','🌎 Geography'])

with tab1: 
    st.markdown('<h3 style="text-align: center; color : black;">Time Period Sales</h3>', unsafe_allow_html=True)
    col= st.selectbox('select feature to see its distribution', ['Month_name','week','week_day','Day_name','Season','Quarter'], key=15)

    df_grouped = df.groupby(col)['Sales'].sum().reset_index()
    # Sort the grouped data in descending order based on the selected column
    df_grouped = df_grouped.sort_values(by=col, ascending=False)

    # Create the line chart
    fig = px.line(
        df_grouped, 
        x=col,  
        y='Sales',                 
        title=f'Sales by {col}',  # Chart title
    ).update_traces(
        line=dict(color=color1[1]),  # Use the second color in the custom color sequence
        mode='lines+markers'         # Add markers to the line
    )
    # Display the line chart in Streamlit
    st.plotly_chart(fig, use_container_width=True)

    
    st.markdown('<h3 style="text-align: center; color : black;">Time Period Profit</h3>', unsafe_allow_html=True)
    col= st.selectbox('select feature to see its distribution', ['Month_name','week','week_day','Day_name','Season','Quarter'], key=16)

    df_grouped = df.groupby(col)['Profit'].sum().reset_index()
    # Sort the grouped data in descending order based on the selected column
    df_grouped = df_grouped.sort_values(by=col, ascending=False)

    # Create the bar chart
    fig = px.bar(
        df_grouped, 
        x=col,  
        y='Profit',                 
        title=f'Profit by {col}', 
        color_discrete_sequence= ['#57B7F2']
    )
    # Display the line chart in Streamlit
    st.plotly_chart(fig, use_container_width=True)


    st.markdown('<h3 style="text-align: center; color : black;">Correlation Heatmap of Time-Based Features</h3>', unsafe_allow_html=True)
    # Select time-based columns for correlation
    time_columns = ['Month_name','week','week_day','Day_name','Season','Quarter']
    # Convert categorical time columns to numerical for correlation calculation
    df_numerical = df[time_columns].apply(lambda x: pd.factorize(x)[0])

    # Add other numerical columns (e.g., 'Sales', 'Profit') if needed
    df_numerical['Sales'] = df['Sales']
    df_numerical['Profit'] = df['Profit']

    # Compute the correlation matrix
    corr_matrix = df_numerical.corr()

    # Create the heatmap using Plotly
    fig = px.imshow(
        corr_matrix,
        text_auto=True,  # Automatically add correlation values to the heatmap
        color_continuous_scale=color1,  # Choose a color scale
    )

    # Update layout for better visualization
    fig.update_layout(
        xaxis_title='Features',
        yaxis_title='Features',
        width=800,
        height=600
    )

    # Display the heatmap in Streamlit
    st.plotly_chart(fig, use_container_width=True)


with tab2: 
    col = st.selectbox('Select feature to see its distribution', ['Region','City','State or Province'])
    st.markdown('<h3 style="text-align: center; color : black;">Sales by Geography</h3>', unsafe_allow_html=True)

    # Create the bar chart
    fig = px.bar(
        df, 
        x=col,  
        y='Sales',                 
        title=f'Sales by {col}', 
        color_discrete_sequence= color1
    )
    # Display the line chart in Streamlit
    st.plotly_chart(fig, use_container_width=True)

    
    col = st.radio('Select feature to see its distribution',['Region','City','State or Province'] , key=20, horizontal=True)
    st.markdown('<h3 style="text-align: center; color : black;">Profit by Geography</h3>', unsafe_allow_html=True)

    # Create the bar chart
    fig = px.bar(
        df, 
        x=col,  
        y='Profit',                 
        title=f'Profit by {col}', 
        color_discrete_sequence= ['#57B7F2']
    )
    # Display the line chart in Streamlit
    st.plotly_chart(fig, use_container_width=True)


    st.markdown('<h3 style="text-align: center; color : black;">Denisty Heatmap BTW Region and State</h3>', unsafe_allow_html=True)
    fig = px.density_heatmap(df,x="Region", y="State or Province",color_continuous_scale=px.colors.sequential.GnBu)

    # Display the line chart in Streamlit
    st.plotly_chart(fig, use_container_width=True)
# Out:
# Overwriting Time_Geography.py

# %%
# %cd ..
# !streamlit run homepage.py
# Out:
# C:\Users\Mohamed Koura\final_proj
